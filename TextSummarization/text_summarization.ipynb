# %%
import os
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

llm = ChatGroq(groq_api_key=groq_api_key,model="Gemma-7b-It")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x708cb10a4d40>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x708cb10a57c0>, model_name='Gemma-7b-It', groq_api_key=SecretStr('**********'))

# %%
from langchain.schema import HumanMessage,AIMessage,SystemMessage

speech = """
 India will celebrate its 78th Independence Day on August 15, 2024. Independence Day is the occasion on which 
 people come together to honour the sacrifices of the freedom fighters who sacrificed their lives to attain independence
 from the British rule. Independence Day is a time to showcase pride and patriotism. It is also a reminder that despite 
 differences in language or tradition, we are all part of one nation. On Independence Day, we join hands to honour the 
 courage of the brave people who fought for our rights.  
"""

speech
# Out:
# '\n India will celebrate its 78th Independence Day on August 15, 2024. Independence Day is the occasion on which \n people come together to honour the sacrifices of the freedom fighters who sacrificed their lives to attain independence\n from the British rule. Independence Day is a time to showcase pride and patriotism. It is also a reminder that despite \n differences in language or tradition, we are all part of one nation. On Independence Day, we join hands to honour the \n courage of the brave people who fought for our rights.  \n'

# %%
chat_message = [
    SystemMessage(content="You are an expert with expertise in summarizing speech"),
    HumanMessage(content="Please provide a short and concise summary of the following speech:{speech}")
]

# %%
llm.get_num_tokens(speech)
# Out:
# 108

# %%
llm(chat_message).content
# Out:
# 'Unfortunately, the speech text is not provided in the context. Please provide the speech text, and I can provide a short and concise summary.'
